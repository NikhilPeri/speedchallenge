# %%
import pandas as pd
# %matplotlib inline

# %%
labels = pd.read_csv('../data/train.txt', header=None, names=['speed'])
labels['frame'] = labels.index

# %%
labels.plot('speed')

# %%
labels.hist('speed')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f7479543b90>]],
#       dtype=object)

# %%
df['bucket_idx'] = pd.cut(labels['speed'], bins=[-1,5,10,15,20,25,30], labels=False)
